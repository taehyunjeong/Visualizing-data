# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="ticks", color_codes=True)

# %%
titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.catplot(data=titanic, x="sex", y="survived", hue="class", kind="bar")

# %%
sns.barplot(data=titanic, x="sex", y="survived", hue="class")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %%
titanic.groupby(["sex"])["survived"].mean()
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %%
titanic.groupby(["sex", "class"])["survived"].mean()
# Out:
# sex     class
# female  First     0.968085
#         Second    0.921053
#         Third     0.500000
# male    First     0.368852
#         Second    0.157407
#         Third     0.135447
# Name: survived, dtype: float64

# %%
titanic_group = titanic.groupby(["sex", "class"])["survived"].mean()
titanic_group.plot.bar()
# Out:
# <AxesSubplot:xlabel='sex,class'>

# %%
titanic_group = titanic_group.unstack()
titanic_group
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
titanic_group.plot.bar()
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
sns.catplot(data=titanic, x="sex", y="survived", hue="class", kind="bar",
            col="embarked")

# %%
sns.catplot(data=titanic, x="sex", y="survived", hue="class", kind="bar",
            col="embarked", ci=None)

# %%
sns.countplot(data=titanic, x="deck")
# Out:
# <AxesSubplot:xlabel='deck', ylabel='count'>

# %%
titanic["deck"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
titanic["deck"].value_counts().sort_index().plot.bar(rot=0)
# Out:
# <AxesSubplot:>

# %%
titanic["deck"].value_counts().sort_index().plot.bar(rot=0, color="r")
# Out:
# <AxesSubplot:>

# %%
sns.countplot(data=titanic, x="deck", palette="ch:.25")
# Out:
# <AxesSubplot:xlabel='deck', ylabel='count'>

# %%
sns.countplot(data=titanic, y="deck", palette="ch:.25")
# Out:
# <AxesSubplot:xlabel='count', ylabel='deck'>

# %%
sns.catplot(data=titanic, y="deck", palette="ch:.25", col="class", kind="count")

# %%
titanic["deck"].value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
sns.catplot(x="deck", y="survived", hue="sex", kind="bar", data=titanic, col="class", ci=None)

# %%
sns.catplot(y="deck", hue="class", kind="count",
            palette="pastel", edgecolor=".6",
            data=titanic)

# %%
sns.catplot(y="deck", kind="count",
            palette="pastel", edgecolor=".6",
            data=titanic)

# %%
sns.catplot(x="sex", y="survived", hue="class", kind="point", data=titanic)

# %%
sns.catplot(x="class", y="survived", hue="sex",
            palette={"male": "g", "female": "m"},
            markers=["^", "o"], linestyles=["-", "--"],
            kind="point", data=titanic)

# %%
sns.catplot(x="class", y="survived", hue="sex",
            palette={"male": "g", "female": "m"},
            markers=["x", "o"], linestyles=[":", "--"],
            kind="point", data=titanic)

# %%
sns.catplot(x="class", y="survived", hue="sex",
            palette={"male": "g", "female": "m"},
            markers=["x", "o"], linestyles=[":", "--"],
            kind="point", data=titanic, col="embarked")

# %%
sns.catplot(data=titanic, orient="h", kind="box")

# %%
sns.catplot(data=titanic, orient="h", kind="violin")

# %%
iris = sns.load_dataset("iris")
sns.violinplot(x=iris.species, y=iris.sepal_length)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
f, ax = plt.subplots(figsize=(7, 3))
sns.countplot(y="deck", data=titanic, color="c")
# Out:
# <AxesSubplot:xlabel='count', ylabel='deck'>

# %%
f, ax = plt.subplots(figsize=(7, 3))
sns.catplot(y="deck", data=titanic, color="c", kind="count")

# catplot 자체가 subplot 이므로 matplolib의 figure에 들어가지 않음

# %%
f, ax = plt.subplots(figsize=(7, 3))
sns.catplot(y="deck", data=titanic, color="c", kind="count", height=3, aspect=3)

# %%
plt.figure(figsize=(7,3))
sns.catplot(y="deck", data=titanic, color="c", kind="count", height=3, aspect=3)

# %%
sns.catplot(y="deck", data=titanic, color="c", kind="count", height=3, aspect=3, col="embarked")

# %%
tips = sns.load_dataset("tips")

sns.catplot(x="day", y="total_bill", hue="smoker",
            col="time", aspect=.7,
            kind="swarm", data=tips)

# %%
sns.catplot(x="day", y="total_bill", hue="smoker", row="sex", 
            col="time", aspect=.7,
            kind="swarm", data=tips)

# %%
g = sns.catplot(x="fare", y="survived", row="class",
                kind="box", orient="h", height=1.5, aspect=4,
                data=titanic.query("fare > 0"))

# %%
g = sns.catplot(x="fare", y="survived", row="class",
                kind="box", orient="h", height=1.5, aspect=4,
                data=titanic.query("fare > 0"))
g.set(xscale="log")
